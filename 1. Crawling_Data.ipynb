# %% [markdown]
# # Crawl Data Twitter > 500 Tweets
# The crawling process was done using Tweet-Harvest.

# %%
#@title Twitter Auth Token

twitter_auth_token = '' # change this auth token

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,801 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,063 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,254 kB]
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,040 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,561 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [4,587 kB]
# Get:17 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,750 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,741 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,351 kB]
# Fetched 32.5 MB in 3s (10.4 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ca-certificates is already the newest version (20240203~22.04.1).
# curl is already the newest version (7.81.0-1ubuntu1.20).
# gnupg is already the newest version (2.2.27-3ubuntu2.3).
# gnupg set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 36 not upgraded.
# deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_20.x nodistro main
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Get:2 https://deb.nodesource.com/node_20.x nodistro InRelease [12.1 kB]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Get:7 https://deb.nodesource.com/node_20.x nodistro/main amd64 Packages [12.1 kB]
# Hit:8 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 24.2 kB in 1s (22.9 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   nodejs
# 0 upgraded, 1 newly installed, 0 to remove and 36 not upgraded.
# Need to get 32.0 MB of archives.
# After this operation, 199 MB of additional disk space will be used.
# Get:1 https://deb.nodesource.com/node_20.x nodistro/main amd64 nodejs amd64 20.19.3-1nodesource1 [32.0 MB]
# Fetched 32.0 MB in 0s (67.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package nodejs.
# (Reading database ... 126308 files and directories currently installed.)
# Preparing to unpack .../nodejs_20.19.3-1nodesource1_amd64.deb ...
# Unpacking nodejs (20.19.3-1nodesource1) ...
# Setting up nodejs (20.19.3-1nodesource1) ...
# Processing triggers for man-db (2.10.2-1) ...
# v20.19.3

# %%
# Crawl Data

filename = 'ikn.csv'
search_keyword = 'ikn lang:id'
limit = 1000

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇npm warn deprecated glob@7.2.3: Glob versions prior to v9 are no longer supported
# ⠇npm warn deprecated rimraf@3.0.2: Rimraf versions prior to v4 are no longer supported
# ⠏npm warn deprecated inflight@1.0.6: This module is not supported, and leaks memory. Do not use it. Check out lru-cache if you want a good and tested way to coalesce async requests by a key value, which is much more comprehensive and powerful.
# ⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1)
# Filling in keywords: ikn lang:id
#
#  (2) (3) (4) (5) (6) (7)Created new directory: /content/tweets-data
#
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 16
#
# -- Scrolling... (1) (2) (3) (4) (5) (6) (7) (8) (9)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 35
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 52
#
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 62
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 78
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 96
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 116
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 130
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 148
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 162
#
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 176
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 194
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 214
#
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 230
#
# --Taking a break, waiting for 10 seconds...
#
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 250
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 267
#
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 280
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 297
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 316
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 333
#
# --Taking a break, waiting for 10 seconds...
#
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 350
#
# -- Scrolling... (1) (2) (3) (4)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 365
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 384
#
# -- Scrolling... (1) (2) (3) (4) (5)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 401
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 412
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 430
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 445
#
# --Taking a break, waiting for 10 seconds...
#
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 462
#
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 478
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 491
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 506
#
# -- Scrolling... (1) (2) (3) (4)
#
# Your tweets saved to: /content/tweets-data/ikn.csv
# Total tweets saved: 523
#
# -- Scrolling... (1) (2)[v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@75ca44a07165cddbe47ad2f8cb73e7b2"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] TimeoutError: page.click: Timeout 60000ms exceeded.
# Call log:
#   - waiting for locator('text=Retry')
#
# Keywords: ikn lang:id
# Twitter Harvest v 2.6.1
#
# If you need help, please send this error screenshot to the maintainer, it was saved to "/content/tweets-data/Error-28-06-2025_03-55-50.png"
# ⠙

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1938673619640688997  Fri Jun 27 18:59:44 +0000 2025               0
# 1    1938673290928857309  Fri Jun 27 18:58:26 +0000 2025               1
# 2    1938672957028737172  Fri Jun 27 18:57:06 +0000 2025               0
# 3    1938672580648673730  Fri Jun 27 18:55:36 +0000 2025               1
# 4    1938670830227198292  Fri Jun 27 18:48:39 +0000 2025               0
# ..                   ...                             ...             ...
# 518  1937346142439952806  Tue Jun 24 08:39:05 +0000 2025               3
# 519  1936615157104525727  Tue Jun 24 08:37:25 +0000 2025               0
# 520  1937371621058314602  Tue Jun 24 08:33:48 +0000 2025               0
# 521  1937427658243195078  Tue Jun 24 08:28:44 +0000 2025               0
# 522  1937385112188178499  Tue Jun 24 08:27:03 +0000 2025               0
#
#                                              full_text               id_str  \
# 0    Kenapa Amerika gak ngebom IKN proyek tolol itu...  1938673619640688997
# 1     Jokowi takut IKN di-Hambalang-kan karena dulu...  1938673290928857309
# 2    Ibu kota harus pindah ke IKN dengan alasan Jak...  1938672957028737172
# 3    Ibu kota dipindah ke IKN karena oligarki penja...  1938672580648673730
# 4    Gedung terminal digenangi air setinggi 5 sampa...  1938670830227198292
# ..                                                 ...                  ...
# 518  @xquitavee @prabowo @jokowi Hah berapa sih har...  1937430264227201397
# 519  @AbasBalapradana Bohongnya Jokowi terlalu bany...  1937429845228814650
# 520                       @IqbalRa17664055 cher-no-ikn  1937428934838354346
# 521  SAR gabungan kembali cari warga hilang di huta...  1937427658243195078
# 522                 @butterplli Harusny di IKN ga sih   1937427236950540378
#
#                                              image_url  \
# 0      https://pbs.twimg.com/media/GueNYSnbYAA2yZI.jpg
# 1    https://pbs.twimg.com/amplify_video_thumb/1938...
# 2    https://pbs.twimg.com/amplify_video_thumb/1938...
# 3      https://pbs.twimg.com/media/GueMb04boAAySuS.jpg
# 4      https://pbs.twimg.com/media/GueK161acAAdZ3s.jpg
# ..                                                 ...
# 518                                                NaN
# 519                                                NaN
# 520                                                NaN
# 521    https://pbs.twimg.com/media/GuMgJCnbsAAtECz.png
# 522                                                NaN
#
#     in_reply_to_screen_name lang  location  quote_count  reply_count  \
# 0                       NaN   in       NaN            0            0
# 1                       NaN   in       NaN            0            0
# 2                       NaN   in       NaN            0            0
# 3                       NaN   in       NaN            0            1
# 4                       NaN   in       NaN            0            0
# ..                      ...  ...       ...          ...          ...
# 518               xquitavee   in       NaN            0            0
# 519         AbasBalapradana   in       NaN            0            0
# 520         IqbalRa17664055   in       NaN            0            0
# 521                     NaN   in       NaN            0            0
# 522              butterplli   in       NaN            0            1
#
#      retweet_count                                          tweet_url  \
# 0                0  https://x.com/undefined/status/193867361964068...
# 1                0  https://x.com/undefined/status/193867329092885...
# 2                0  https://x.com/undefined/status/193867295702873...
# 3                1  https://x.com/undefined/status/193867258064867...
# 4                0  https://x.com/undefined/status/193867083022719...
# ..             ...                                                ...
# 518              0  https://x.com/undefined/status/193743026422720...
# 519              0  https://x.com/undefined/status/193742984522881...
# 520              0  https://x.com/undefined/status/193742893483835...
# 521              0  https://x.com/undefined/status/193742765824319...
# 522              0  https://x.com/undefined/status/193742723695054...
#
#              user_id_str  username
# 0    1604064608913723394       NaN
# 1    1604064608913723394       NaN
# 2    1604064608913723394       NaN
# 3    1604064608913723394       NaN
# 4    1604064608913723394       NaN
# ..                   ...       ...
# 518  1810722801801932800       NaN
# 519   984467069172269056       NaN
# 520   900624461778493440       NaN
# 521  1482999200988434435       NaN
# 522  1170941604116324352       NaN
#
# [523 rows x 15 columns]

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 523.
